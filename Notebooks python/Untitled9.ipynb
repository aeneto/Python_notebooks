# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn
import statistics as sts

# %%
base = pd.read_csv('tabelas.csv', sep = ';')
base.head()
# Out:
#        schema                     tabela   linhas  Quantidade de linhas  \
# 0   mpf_simba   amostra_dados_cadastrais    23876                 23876
# 1   mpf_simba  amostra_extrato_detalhado  1182933               1182933
# 2  mpf_sittel                  assinante     5274                  5274
# 3  mpf_sittel                    chamada   376795                376795
# 4   mpf_radar                       cnpj     9999                  9999
#
#    quantidade de colunas  instancias duplicadas
# 0                     17                      0
# 1                     28                      0
# 2                     15                      0
# 3                     30                      0
# 4                     34                      0

# %%
base.describe()
# Out:
#              linhas  Quantidade de linhas  quantidade de colunas  \
# count  2.150000e+02          2.150000e+02             215.000000
# mean   1.555944e+04          1.555944e+04              15.720930
# std    8.391232e+04          8.391232e+04              11.132435
# min    2.300000e+01          2.300000e+01               4.000000
# 25%    9.999000e+03          9.999000e+03               9.000000
# 50%    9.999000e+03          9.999000e+03              12.000000
# 75%    9.999000e+03          9.999000e+03              19.000000
# max    1.182933e+06          1.182933e+06              89.000000
#
#        instancias duplicadas
# count             215.000000
# mean                0.688372
# std                 9.821805
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max               144.000000

# %%
srn.boxplot(dataset['linhas']).set_title('linhas')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-423c848805b1> in <module>
# ----> 1 srn.boxplot(dataset['base']).set_title('linhas')
#
# NameError: name 'dataset' is not defined
